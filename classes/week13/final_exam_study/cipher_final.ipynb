# %% [markdown]
# Encode/Decode with Custom Alphabet
#
#
# Cipher Practice Questions
# Final Exam Preparation
# ----------------------
#
# This file contains 5 encoding/decoding questions
# using non-English custom alphabets.
# Each question is independent and includes all needed data.

# %% [markdown]
# 1. Known Caesar Shift (Emoji Alphabet)
#
#
# """
# Alphabet:
#     ['😀','😁','😂','🤣','😃','😄','😅','😆']
#
# Task:
#     Using a shift of +3 (to the right), encode the message:
#
#         😀 😄 😁
#
#     Apply wraparound and write the final encoded sequence.
# """

# %%
alphabet = ['😀','😁','😂','🤣','😃','😄','😅','😆']
msg = 😀 😄 😁

alphabet = ['😀','😁','😂','🤣','😃','😄','😅','😆']

shift = 3
shifted = alphabet[shift:] + alphabet[:shift]

print(shifted)

# %% [markdown]
# 2. Caesar Shift Function (Shape Alphabet)
#
# """
# Alphabet:
#     ['▲','■','●','◆','★','✦']
#
# Task:
#     Write a Python function:
#
#         encode(msg, shift, alphabet)
#
#     that performs a Caesar shift on the given alphabet.
#
#     Then compute:
#
#         encode('■◆▲', 4, alphabet)
# """

# %%
#code

# %% [markdown]
# Substitution Cipher (Rune Alphabet)
#
# """
# Plaintext Alphabet:
#     ['ᚠ','ᚢ','ᚦ','ᚨ','ᚱ','ᚲ']
#
# Cipher Alphabet (substitution mapping, index-aligned):
#     ['Ψ','Ω','Σ','Δ','Φ','Λ']
#
# Tasks:
#     1. Encode the message:
#
#           ᚨ ᚲ ᚱ ᚢ
#
#     2. Decode the message:
#
#           Σ Δ Λ
# """

# %%
#code

# %% [markdown]
# Decode Without Knowing the Shift (Symbol Alphabet)
#
# """
# Alphabet:
#     ['@', '#', '$', '%', '&', '*', '+']
#
# Ciphertext:
#     % @ + @ #
#
# Task:
#     The ciphertext was encoded using an unknown Caesar shift.
#     Perform a brute-force search (try all shifts) and determine:
#
#         - The correct shift value
#         - The decoded plaintext message
# """

# %%
#code

# %% [markdown]
# Mapping Between Two Alphabets
#
#
# """
# Alphabet A:
#     ['α','β','γ','δ']
#
# Alphabet B:
#     ['sun','moon','star','cloud']
#
# (Aligned by index: α→sun, β→moon, γ→star, δ→cloud)
#
# Tasks:
#     1. Encode the message:
#
#           γ α δ
#
#        into Alphabet B.
#
#     2. Decode the sequence:
#
#           cloud sun moon
#
#        back into Alphabet A.
# """

# %%
#code
